# %% [markdown]
# # Activity: Basic Exploration
#
# ## Introduction
#
# In this activity you will practice using exploration methods on a data set containing games of online chess*.
# This activity includes some or all of the following, not necessarily in this order:
# - Viewing the data
# - Finding the mean
# - Finding the median
# - Standard deviation
# - Aggregations
# - Grouping
#
# *The data set is from [Kaggle](https://www.kaggle.com/datasets/mysarahmadbhat/online-chess-games).

# %% [markdown]
# ## Note
#
# This data set is larger than those used in previous activities. Please run the cell below which uses the `info()` method to get a sense of the data before you begin.

# %%
import pandas as pd

df = pd.read_csv('chess_games.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20058 entries, 0 to 20057
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_id            20058 non-null  int64
#  1   rated              20058 non-null  bool
#  2   turns              20058 non-null  int64
#  3   victory_status     20058 non-null  object
#  4   winner             20058 non-null  object
#  5   time_increment     20058 non-null  object
#  6   white_id           20058 non-null  object
#  7   white_rating       20058 non-null  int64
#  8   black_id           20058 non-null  object
#  9   black_rating       20058 non-null  int64
#  10  moves              20058 non-null  object
#  11  opening_code       20058 non-null  object
#  12  opening_moves      20058 non-null  int64
#  13  opening_fullname   20058 non-null  object
#  14  opening_shortname  20058 non-null  object
#  15  opening_response   1207 non-null   object
# ...

# %%
import seaborn as sns

# %% [markdown]
# #### Question 1
#
# Create two `DataFrame` objects called `first_three` and `last_three` and assign the first and last three rows of the data set to them, respectively.

# %%
# Your code here


first_three = df.head(3)

last_three = df.tail(3)

# %%
# Question 1 Grading Checks

assert first_three.shape == (3, 17), 'Make sure that you chose only the first three rows.'
assert last_three.shape == (3, 17), 'Make sure that you chose only the last three rows.'

# %% [markdown]
# #### Question 2
#
# Create a variable called `white_rating_mean` that is assigned the mean value of the `white_rating` column, and a variable called `black_rating_mean` that is assigned the mean value of the `black_rating` column.

# %%
# Your code here


white_rating_mean = df.white_rating.mean()

black_rating_mean = df.black_rating.mean()

# %%
# Question 2 Grading Checks

assert white_rating_mean < 1600, 'Make sure that you are calculating the mean of the white_rating column.'
assert black_rating_mean < 1600, 'Make sure that you are calculating the mean of the black_rating column.'

# %% [markdown]
# #### Question 3
#
# Create two new `DataFrame` objects called `white_lower_rating` and `white_higher_rating` that are assigned the rows of data where the white player's rating is less than 1200 and greater than or equal to 1800, respectively.

# %%
# Your code here

white_lower_rating = pd.DataFrame(df[df.white_rating < 1200])

white_higher_rating = pd.DataFrame(df[df.white_rating >= 1800])

# %%
# Question 3 Grading Checks

assert isinstance(white_lower_rating, pd.DataFrame), 'Make sure that you are creating a DataFrame object called white_lower_rating.'
assert isinstance(white_higher_rating, pd.DataFrame), 'Make sure that you are creating a DataFrame object called white_higher_rating.'

# %% [markdown]
# #### Question 4
#
# Using the `white_lower_rating` and `white_higher_rating` `DataFrame` objects from Question 3, get the mean number of turns for games that were lower and higher, respectively, and assign them to the variables `white_lower_turns_mean` and `white_higher_turns_mean`.

# %%
# Your code here
white_lower_rating
# Out:
#        game_id  rated  turns victory_status winner time_increment  \
# 14          15  False     31           Mate  White          15+15
# 15          16  False     43         Resign  Black          15+15
# 16          17  False     52         Resign  Black          15+15
# 17          18  False     66           Mate  Black          15+16
# 18          19  False    101         Resign  Black          15+15
# ...        ...    ...    ...            ...    ...            ...
# 19840    19841  False     95         Resign  White           10+0
# 19859    19860  False     46           Mate  Black           10+0
# 19894    19895   True     54           Mate  Black           10+0
# 19921    19922   True     54           Mate  Black          30+30
# 20037    20038   True     32           Mate  Black           10+0
#
#                 white_id  white_rating           black_id  black_rating  \
# 14     shivangithegenius          1094      sureka_akshat          1141
# ...

# %%
white_higher_rating
# Out:
#        game_id  rated  turns victory_status winner time_increment  \
# 26          27   True     43         Resign  White          10+10
# 39          40  False     34         Resign  White          30+30
# 43          44  False     66         Resign  White          40+40
# 48          49  False     35           Mate  White          40+40
# 49          50  False     41           Mate  White          40+40
# ...        ...    ...    ...            ...    ...            ...
# 20026    20027   True     80         Resign  Black           10+0
# 20027    20028   True     47           Mate  White           10+0
# 20028    20029   True    115           Mate  White           10+0
# 20029    20030   True     37         Resign  Black          15+15
# 20030    20031   True     82         Resign  Black          15+15
#
#            white_id  white_rating           black_id  black_rating  \
# 26     gmcarlsen403          1825  shivangithegenius          1079
# ...

# %%
white_lower_turns_mean = white_lower_rating.turns.mean()
white_lower_turns_mean
# Out:
# 50.63425345043915

# %%
white_higher_turns_mean = white_higher_rating.turns.mean()
white_higher_turns_mean
# Out:
# 65.80102459016393

# %%
# Question 4 Grading Checks

assert white_lower_turns_mean < 60, 'Make sure that you are calculating the mean number of turns for games where the white player\'s rating is less than 1200.'
assert white_higher_turns_mean < 70, 'Make sure that you are calculating the mean number of turns for games where the white player\'s rating is greater than or equal to 1800.'

# %% [markdown]
# #### Question 5
#
# Using the `black_rating` column, create a `DataFrame` object called `top_10_percent_black` which is assigned the top 10% of black players by rating. That is, the only rows of where the `black_rating` is higher than 90% of all the `black_rating` values.

# %%
# Your code here


df.black_rating
# Out:
# 0        1191
# 1        1261
# 2        1500
# 3        1454
# 4        1469
#          ...
# 20053    1220
# 20054    1196
# 20055    1286
# 20056    1227
# 20057    1339
# Name: black_rating, Length: 20058, dtype: int64

# %%
df.black_rating.describe()
# Out:
# count    20058.000000
# mean      1588.831987
# std        291.036126
# min        789.000000
# 25%       1391.000000
# 50%       1562.000000
# 75%       1784.000000
# max       2723.000000
# Name: black_rating, dtype: float64

# %%
sns.boxplot(data=df.black_rating);

# %%
df['black_rating'].quantile(0.90)
# Out:
# 1978.0

# %%
df['black_rating'].nlargest(n=2011)
# Out:
# 4473     2723
# 5373     2621
# 5374     2621
# 11597    2621
# 11601    2621
#          ...
# 9695     1978
# 11384    1978
# 13475    1978
# 13536    1978
# 13564    1978
# Name: black_rating, Length: 2011, dtype: int64

# %%
top_10_percent_black = df[df['black_rating'] >= df['black_rating'].quantile(0.9)]
top_10_percent_black.head()
# Out:
#      game_id  rated  turns victory_status winner time_increment  \
# 7          8  False      9         Resign  Black          15+30
# 78        79   True     47         Resign  Black           15+5
# 203      204   True     28         Resign  Black            7+2
# 291      292   True     69           Draw   Draw           20+0
# 364      365   True     40         Resign  Black           10+0
#
#                white_id  white_rating        black_id  black_rating  \
# 7    daniel_likes_chess          1413        soultego          2108
# 78             oldpaths          1579  iris_foxspring          2105
# 203             taranga          1289   hknight_chess          2108
# 291          nadanadora          1611   qaisahleyorof          2059
# 364   joselito-carnaval          1780    arjunshenoyk          2132
#
#                                                  moves opening_code  \
# 7                       e4 Nc6 d4 e5 d5 Nce7 c3 Ng6 b4          B00
# ...

# %%
top_10_percent_black.shape
# Out:
# (2011, 17)

# %%
# Question 5 Grading Checks

assert top_10_percent_black.shape == (2011, 17), 'Make sure that you are selecting the top 10% of black players by rating. Hint: Try using a conditional statement to check which black_rating values are in the top 10%.'

# %% [markdown]
# #### Question 6
#
# Using the `top_10_percent_black` `DataFrame` object from Question 5, create a mask called `rated_mask` which filters out all games which were not `rated`.

# %%
top_10_percent_black.head()
# Out:
#      game_id  rated  turns victory_status winner time_increment  \
# 7          8  False      9         Resign  Black          15+30
# 78        79   True     47         Resign  Black           15+5
# 203      204   True     28         Resign  Black            7+2
# 291      292   True     69           Draw   Draw           20+0
# 364      365   True     40         Resign  Black           10+0
#
#                white_id  white_rating        black_id  black_rating  \
# 7    daniel_likes_chess          1413        soultego          2108
# 78             oldpaths          1579  iris_foxspring          2105
# 203             taranga          1289   hknight_chess          2108
# 291          nadanadora          1611   qaisahleyorof          2059
# 364   joselito-carnaval          1780    arjunshenoyk          2132
#
#                                                  moves opening_code  \
# 7                       e4 Nc6 d4 e5 d5 Nce7 c3 Ng6 b4          B00
# ...

# %%
# Your code here


rated_mask = top_10_percent_black.rated == True

# %%
rated_mask.head()
# Out:
# 7      False
# 78      True
# 203     True
# 291     True
# 364     True
# Name: rated, dtype: bool

# %%
rated_mask.sum()
# Out:
# 1643

# %%
# Question 6 Grading Checks

assert rated_mask.sum() == 1643, 'Make sure that you are filtering out all games which were not rated.'

# %% [markdown]
# #### Question 7
#
# Using the `top_10_percent_black` `DataFrame` object from Question 5, and the `rated_mask` from Question 6, aggregate the mean, median, and standard deviation of the `white_rating` column for the rated games and assign the result to a variable called `top_10_percent_black_stats`.

# %%
# Your code here


top_10_percent_black.head()
# Out:
#      game_id  rated  turns victory_status winner time_increment  \
# 7          8  False      9         Resign  Black          15+30
# 78        79   True     47         Resign  Black           15+5
# 203      204   True     28         Resign  Black            7+2
# 291      292   True     69           Draw   Draw           20+0
# 364      365   True     40         Resign  Black           10+0
#
#                white_id  white_rating        black_id  black_rating  \
# 7    daniel_likes_chess          1413        soultego          2108
# 78             oldpaths          1579  iris_foxspring          2105
# 203             taranga          1289   hknight_chess          2108
# 291          nadanadora          1611   qaisahleyorof          2059
# 364   joselito-carnaval          1780    arjunshenoyk          2132
#
#                                                  moves opening_code  \
# 7                       e4 Nc6 d4 e5 d5 Nce7 c3 Ng6 b4          B00
# ...

# %%
top_10_percent_black[rated_mask]
# Out:
#        game_id  rated  turns victory_status winner time_increment  \
# 78          79   True     47         Resign  Black           15+5
# 203        204   True     28         Resign  Black            7+2
# 291        292   True     69           Draw   Draw           20+0
# 364        365   True     40         Resign  Black           10+0
# 396        397   True     31         Resign  Black            5+5
# ...        ...    ...    ...            ...    ...            ...
# 20013    20014   True     95         Resign  Black          45+45
# 20014    20015   True    109           Draw   Draw          45+45
# 20015    20016   True     42         Resign  Black           7+30
# 20016    20017   True    102         Resign  Black           7+30
# 20017    20018   True     97         Resign  White          60+30
#
#                 white_id  white_rating        black_id  black_rating  \
# 78              oldpaths          1579  iris_foxspring          2105
# ...

# %%
top_10_percent_black_stats = top_10_percent_black[rated_mask].white_rating.agg(["mean", "median","std"])
top_10_percent_black_stats
# Out:
# mean      1971.265977
# median    2003.000000
# std        245.920014
# Name: white_rating, dtype: float64

# %%
# Question 7 Grading Checks

assert top_10_percent_black_stats.shape == (3,), 'Make sure that you are aggregating the mean, median, and standard deviation of the white_rating column.'
