# %%
for count in range(1,5):
    print(count)
    if count > 1:
        print("Hello")
    elif count <= 3:
        print("Hi")
    else:
        print("*")

print("All Done")
# Out:
# 1
# Hi
# 2
# Hello
# 3
# Hello
# 4
# Hello
# All Done

# %%
my_list = [10,30,40]

if my_list[1] < 20:
   print('first')
elif len(my_list) == 2:
   print('second')
elif my_list[0] + 25 > my_list[1]:
   print('third')
elif len(my_list) > 1:
   print('fourth')
# Out:
# third
